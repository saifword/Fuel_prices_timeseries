# %% [markdown]
# <a href="https://colab.research.google.com/github/saifword/Fuel_prices_timeseries/blob/master/passengers_m.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_2012 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/data/2012.csv')
df_2013 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/data/2013.csv')
df_2014 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/data/2014.csv')
df_2015 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/data/2015.csv')
df_2016 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/data/2016.csv')
df_2017 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/data/2017.csv')
df_2018 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/data/2018.csv')
df_2019 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/data/2019.csv')
df_2020 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/data/2020.csv')
#from google.colab import files
#uploaded = files.upload()

# %%
df_2012
# Out:
#         DEPARTURES_SCHEDULED  DEPARTURES_PERFORMED  ...  MONTH  Unnamed: 24
# 0                        0.0                   1.0  ...      1          NaN
# 1                        0.0                   1.0  ...      1          NaN
# 2                        0.0                   1.0  ...      1          NaN
# 3                        0.0                   1.0  ...      1          NaN
# 4                        0.0                   1.0  ...      1          NaN
# ...                      ...                   ...  ...    ...          ...
# 390003                1284.0                   4.0  ...     10          NaN
# 390004                1302.0                  10.0  ...     10          NaN
# 390005                2003.0                   7.0  ...     10          NaN
# 390006                2072.0                   9.0  ...     10          NaN
# 390007                2876.0                  11.0  ...     10          NaN
#
# [390008 rows x 25 columns]

# %%
df_2012.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 390008 entries, 0 to 390007
# Data columns (total 25 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   DEPARTURES_SCHEDULED  390008 non-null  float64
#  1   DEPARTURES_PERFORMED  390008 non-null  float64
#  2   SEATS                 390008 non-null  float64
#  3   PASSENGERS            390008 non-null  float64
#  4   DISTANCE              390008 non-null  float64
#  5   AIR_TIME              390008 non-null  float64
#  6   UNIQUE_CARRIER        389922 non-null  object
#  7   UNIQUE_CARRIER_NAME   390008 non-null  object
#  8   ORIGIN                390008 non-null  object
#  9   ORIGIN_CITY_NAME      390008 non-null  object
#  10  ORIGIN_STATE_ABR      371332 non-null  object
#  11  ORIGIN_STATE_NM       371332 non-null  object
#  12  ORIGIN_COUNTRY        390008 non-null  object
#  13  ORIGIN_COUNTRY_NAME   390008 non-null  object
# ...

# %%
df_2012.PASSENGERS.max()
# Out:
# 82988.0

# %%
df_2012.SEATS.max()
# Out:
# 108372.0

# %%
df_2012 = df_2012[df_2012['MONTH'] >= 3]

# %%
df_2012.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 328216 entries, 729 to 390007
# Data columns (total 25 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   DEPARTURES_SCHEDULED  328216 non-null  float64
#  1   DEPARTURES_PERFORMED  328216 non-null  float64
#  2   SEATS                 328216 non-null  float64
#  3   PASSENGERS            328216 non-null  float64
#  4   DISTANCE              328216 non-null  float64
#  5   AIR_TIME              328216 non-null  float64
#  6   UNIQUE_CARRIER        328156 non-null  object
#  7   UNIQUE_CARRIER_NAME   328216 non-null  object
#  8   ORIGIN                328216 non-null  object
#  9   ORIGIN_CITY_NAME      328216 non-null  object
#  10  ORIGIN_STATE_ABR      312715 non-null  object
#  11  ORIGIN_STATE_NM       312715 non-null  object
#  12  ORIGIN_COUNTRY        328216 non-null  object
#  13  ORIGIN_COUNTRY_NAME   328216 non-null  object
# ...

# %%
df_2020
# Out:
#         DEPARTURES_SCHEDULED  DEPARTURES_PERFORMED  ...  MONTH  Unnamed: 24
# 0                        0.0                   1.0  ...      2          NaN
# 1                        0.0                   1.0  ...      2          NaN
# 2                        0.0                   1.0  ...      2          NaN
# 3                        0.0                   1.0  ...      2          NaN
# 4                        0.0                   1.0  ...      2          NaN
# ...                      ...                   ...  ...    ...          ...
# 328364                 750.0                 690.0  ...      3          NaN
# 328365                 804.0                 802.0  ...      1          NaN
# 328366                 804.0                 803.0  ...      1          NaN
# 328367                1076.0                1076.0  ...      1          NaN
# 328368                1108.0                1108.0  ...      1          NaN
#
# [328369 rows x 25 columns]

# %%
df_2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 328369 entries, 0 to 328368
# Data columns (total 25 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   DEPARTURES_SCHEDULED  328369 non-null  float64
#  1   DEPARTURES_PERFORMED  328369 non-null  float64
#  2   SEATS                 328369 non-null  float64
#  3   PASSENGERS            328369 non-null  float64
#  4   DISTANCE              328369 non-null  float64
#  5   AIR_TIME              328369 non-null  float64
#  6   UNIQUE_CARRIER        328365 non-null  object
#  7   UNIQUE_CARRIER_NAME   328365 non-null  object
#  8   ORIGIN                328369 non-null  object
#  9   ORIGIN_CITY_NAME      328369 non-null  object
#  10  ORIGIN_STATE_ABR      313300 non-null  object
#  11  ORIGIN_STATE_NM       313300 non-null  object
#  12  ORIGIN_COUNTRY        328369 non-null  object
#  13  ORIGIN_COUNTRY_NAME   328369 non-null  object
# ...

# %%
df_2020 = df_2020[df_2020['MONTH'] <=2]

# %%
df_2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 73342 entries, 0 to 328368
# Data columns (total 25 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   DEPARTURES_SCHEDULED  73342 non-null  float64
#  1   DEPARTURES_PERFORMED  73342 non-null  float64
#  2   SEATS                 73342 non-null  float64
#  3   PASSENGERS            73342 non-null  float64
#  4   DISTANCE              73342 non-null  float64
#  5   AIR_TIME              73342 non-null  float64
#  6   UNIQUE_CARRIER        73338 non-null  object
#  7   UNIQUE_CARRIER_NAME   73338 non-null  object
#  8   ORIGIN                73342 non-null  object
#  9   ORIGIN_CITY_NAME      73342 non-null  object
#  10  ORIGIN_STATE_ABR      69628 non-null  object
#  11  ORIGIN_STATE_NM       69628 non-null  object
#  12  ORIGIN_COUNTRY        73342 non-null  object
#  13  ORIGIN_COUNTRY_NAME   73342 non-null  object
# ...

# %%
df = df_2012.append([df_2013, df_2014, df_2015, df_2016, df_2017, df_2018
                     , df_2019, df_2020])

# %%
df
# Out:
#         DEPARTURES_SCHEDULED  DEPARTURES_PERFORMED  ...  MONTH  Unnamed: 24
# 729                      0.0                   1.0  ...      3          NaN
# 730                      0.0                   1.0  ...      7          NaN
# 731                      0.0                   1.0  ...      7          NaN
# 732                      0.0                   5.0  ...      7          NaN
# 733                      0.0                   1.0  ...      7          NaN
# ...                      ...                   ...  ...    ...          ...
# 328362                 747.0                 745.0  ...      2          NaN
# 328365                 804.0                 802.0  ...      1          NaN
# 328366                 804.0                 803.0  ...      1          NaN
# 328367                1076.0                1076.0  ...      1          NaN
# 328368                1108.0                1108.0  ...      1          NaN
#
# [3336831 rows x 25 columns]
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3336831 entries, 729 to 328368
# Data columns (total 25 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   DEPARTURES_SCHEDULED  float64
#  1   DEPARTURES_PERFORMED  float64
#  2   SEATS                 float64
#  3   PASSENGERS            float64
#  4   DISTANCE              float64
#  5   AIR_TIME              float64
#  6   UNIQUE_CARRIER        object
#  7   UNIQUE_CARRIER_NAME   object
#  8   ORIGIN                object
#  9   ORIGIN_CITY_NAME      object
#  10  ORIGIN_STATE_ABR      object
#  11  ORIGIN_STATE_NM       object
#  12  ORIGIN_COUNTRY        object
#  13  ORIGIN_COUNTRY_NAME   object
#  14  DEST                  object
#  15  DEST_CITY_NAME        object
#  16  DEST_STATE_ABR        object
#  17  DEST_STATE_NM         object
#  18  DEST_COUNTRY          object
#  19  DEST_COUNTRY_NAME     object
#  20  AIRCRAFT_TYPE         int64
#  21  YEAR                  int64
# ...

# %%
df_ua = df[df['UNIQUE_CARRIER_NAME'] == 'United Air Lines Inc.']

# %%
df_ua
# Out:
#         DEPARTURES_SCHEDULED  DEPARTURES_PERFORMED  ...  MONTH  Unnamed: 24
# 730                      0.0                   1.0  ...      7          NaN
# 731                      0.0                   1.0  ...      7          NaN
# 732                      0.0                   5.0  ...      7          NaN
# 733                      0.0                   1.0  ...      7          NaN
# 734                      0.0                   1.0  ...      7          NaN
# ...                      ...                   ...  ...    ...          ...
# 327313                 189.0                 189.0  ...      1          NaN
# 327452                 199.0                 199.0  ...      2          NaN
# 327455                 200.0                 200.0  ...      2          NaN
# 327630                 214.0                 214.0  ...      1          NaN
# 327632                 214.0                 214.0  ...      1          NaN
#
# [292139 rows x 25 columns]

# %%
#df_ua.to_csv(index=False)

# %%
df_ua.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 292139 entries, 730 to 327632
# Data columns (total 25 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   DEPARTURES_SCHEDULED  292139 non-null  float64
#  1   DEPARTURES_PERFORMED  292139 non-null  float64
#  2   SEATS                 292139 non-null  float64
#  3   PASSENGERS            292139 non-null  float64
#  4   DISTANCE              292139 non-null  float64
#  5   AIR_TIME              292139 non-null  float64
#  6   UNIQUE_CARRIER        292139 non-null  object
#  7   UNIQUE_CARRIER_NAME   292139 non-null  object
#  8   ORIGIN                292139 non-null  object
#  9   ORIGIN_CITY_NAME      292139 non-null  object
#  10  ORIGIN_STATE_ABR      259927 non-null  object
#  11  ORIGIN_STATE_NM       259927 non-null  object
#  12  ORIGIN_COUNTRY        292139 non-null  object
#  13  ORIGIN_COUNTRY_NAME   292139 non-null  object
# ...

# %% [markdown]
# * The size of the dataframe is much more managable now.
# * With the smaller size, the info() function is giving us the non-null count.
#     * Missing values appear to only be in the Origin and Destination states data.
#     * I suspect those are international flights.

# %%
df_ua[df_ua['ORIGIN_COUNTRY'] != 'US']
# Out:
#         DEPARTURES_SCHEDULED  DEPARTURES_PERFORMED  ...  MONTH  Unnamed: 24
# 756                      0.0                   1.0  ...      7          NaN
# 14766                    0.0                   1.0  ...     11          NaN
# 14767                    0.0                   1.0  ...     11          NaN
# 14768                    0.0                   1.0  ...     11          NaN
# 14769                    0.0                   1.0  ...     11          NaN
# ...                      ...                   ...  ...    ...          ...
# 320344                 103.0                 104.0  ...      1          NaN
# 320844                 106.0                 106.0  ...      1          NaN
# 321330                 109.0                 109.0  ...      2          NaN
# 324733                 132.0                 125.0  ...      2          NaN
# 324795                 133.0                 132.0  ...      1          NaN
#
# [36437 rows x 25 columns]

# %% [markdown]
# * It appears we do have state names for Canada.  Let's check

# %%
df_ua.AIRCRAFT_TYPE.unique()
# Out:
# array([614, 698, 622, 623, 634, 626, 612, 694, 616, 627, 819, 624, 887,
#        625, 889, 637, 888, 839, 837])

# %%
df_ua.DEPARTURES_SCHEDULED
# Out:
# 730         0.0
# 731         0.0
# 732         0.0
# 733         0.0
# 734         0.0
#           ...
# 327313    189.0
# 327452    199.0
# 327455    200.0
# 327630    214.0
# 327632    214.0
# Name: DEPARTURES_SCHEDULED, Length: 292139, dtype: float64

# %%
how_full = df_ua['PASSENGERS']/df_ua['SEATS']

# %%
how_full.describe()
# Out:
# count    291828.000000
# mean          0.812870
# std           0.150333
# min           0.000000
# 25%           0.752566
# 50%           0.856173
# 75%           0.917598
# max           1.000000
# dtype: float64

# %%
per_route = df_ua[['ORIGIN', 'DEST', 'YEAR', 'MONTH', 'PASSENGERS']]

# %%
per_route
# Out:
#        ORIGIN DEST  YEAR  MONTH  PASSENGERS
# 730       IAH  SFO  2012      7        42.0
# 731       IAH  SMF  2012      7       120.0
# 732       IAH  SNA  2012      7       588.0
# 733       IAH  TUL  2012      7       138.0
# 734       JAX  FLL  2012      7       141.0
# ...       ...  ...   ...    ...         ...
# 327313    IAH  DEN  2020      1     30333.0
# 327452    EWR  SFO  2020      2     24889.0
# 327455    SFO  EWR  2020      2     25278.0
# 327630    EWR  SFO  2020      1     28653.0
# 327632    SFO  EWR  2020      1     27098.0
#
# [292139 rows x 5 columns]

# %% [markdown]
# Here is what I want to do with this.
# * Turn Origin and destination into a tuple
# * Get the sum of the passengers traveling the route each way
# * Do a groupby on Year eventually in order to see trends.

# %% [markdown]
# Our hub airports:
#
# *   Chicago, IL — O'Hare International Airport (ORD)
# *   Denver, CO — Denver International Airport (DEN)
# *   ~~Guam — Antonio B. Won Pat International Airport (GUM)~
# *   Houston, TX — Houston/ George Bush Intercontinental Airport (IAH)
# *   Los Angeles, CA — Los Angeles International Airport (LAX)
# *   New York, NY/Newark, NJ — Newark Liberty International Airport (EWR) [our New York area hub]
# *   San Francisco, CA — San Francisco International Airport (SFO)
# *   Washington, D.C. — Washington Dulles International Airport (IAD)
#
# Other key airports:
#
# *   Frankfurt, Germany — Frankfurt International Airport (FRA)
# *   Hong Kong — Hong Kong International Airport (HKG)
# *   London, United Kingdom — London Heathrow International Airport (LHR)
# *   *New York, NY — LaGuardia Airport (LGA)*
# *   São Paulo, Brazil — Guarulhos International Airport (GRU)
# *   Tokyo, Japan — Tokyo Haneda Airport (HND)
# *   Tokyo, Japan — Tokyo Narita Airport (NRT)

# %%
airports = per_route.ORIGIN.unique()

# %%
airports[1]
# Out:
# 'JAX'

# %%
airports.shape
# Out:
# (416,)

# %%
per_route['ROUTE'] = per_route[['ORIGIN', 'DEST']].apply(set, axis=1)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
per_route
# Out:
#        ORIGIN DEST  YEAR  MONTH  PASSENGERS       ROUTE
# 730       IAH  SFO  2012      7        42.0  {IAH, SFO}
# 731       IAH  SMF  2012      7       120.0  {IAH, SMF}
# 732       IAH  SNA  2012      7       588.0  {SNA, IAH}
# 733       IAH  TUL  2012      7       138.0  {TUL, IAH}
# 734       JAX  FLL  2012      7       141.0  {JAX, FLL}
# ...       ...  ...   ...    ...         ...         ...
# 327313    IAH  DEN  2020      1     30333.0  {DEN, IAH}
# 327452    EWR  SFO  2020      2     24889.0  {SFO, EWR}
# 327455    SFO  EWR  2020      2     25278.0  {SFO, EWR}
# 327630    EWR  SFO  2020      1     28653.0  {SFO, EWR}
# 327632    SFO  EWR  2020      1     27098.0  {SFO, EWR}
#
# [292139 rows x 6 columns]

# %%
df_rpy = per_route[['ROUTE', 'YEAR', 'MONTH', 'PASSENGERS']]

# %%
df_rpy
# Out:
#              ROUTE  YEAR  MONTH  PASSENGERS
# 730     {IAH, SFO}  2012      7        42.0
# 731     {IAH, SMF}  2012      7       120.0
# 732     {SNA, IAH}  2012      7       588.0
# 733     {TUL, IAH}  2012      7       138.0
# 734     {JAX, FLL}  2012      7       141.0
# ...            ...   ...    ...         ...
# 327313  {DEN, IAH}  2020      1     30333.0
# 327452  {SFO, EWR}  2020      2     24889.0
# 327455  {SFO, EWR}  2020      2     25278.0
# 327630  {SFO, EWR}  2020      1     28653.0
# 327632  {SFO, EWR}  2020      1     27098.0
#
# [292139 rows x 4 columns]

# %%
f"Year is {df_rpy['YEAR']}-{df_rpy['MONTH']}"
# Out:
# 'Year is 730       2012\n731       2012\n732       2012\n733       2012\n734       2012\n          ... \n327313    2020\n327452    2020\n327455    2020\n327630    2020\n327632    2020\nName: YEAR, Length: 292139, dtype: int64-730       7\n731       7\n732       7\n733       7\n734       7\n         ..\n327313    1\n327452    2\n327455    2\n327630    1\n327632    1\nName: MONTH, Length: 292139, dtype: int64'

# %%
yearly = df_rpy.groupby('YEAR').sum()

# %%
month =df_rpy.groupby('MONTH').sum()

# %%
yearly
# Out:
#        MONTH   PASSENGERS
# YEAR
# 2012  221532   78784398.0
# 2013  222457   89969540.0
# 2014  223990   90542699.0
# 2015  234740   95532051.0
# 2016  235996  100371708.0
# 2017  242646  107571934.0
# 2018  255922  113668262.0
# 2019  273552  116742820.0
# 2020    9650   16688065.0

# %%
sns.barplot(x=yearly.index, y=yearly.PASSENGERS)

# %%
sns.barplot(x=month.index, y=month.PASSENGERS)
